# %% [markdown]
# # Stack Overflow Developer Survey 2022 Dataset
# ## Exploratory Data Analysis

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
df = pd.read_csv("../data/survey_results_public.csv")

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
df.describe(include= 'all').T[:20]
# Out:
#                           count unique  \
# ResponseId              73268.0    NaN
# MainBranch                73268      6
# Employment                71709    103
# RemoteWork                58958      3
# CodingActivities          58899     63
# EdLevel                   71571      9
# LearnCode                 71580    737
# LearnCodeOnline           50685   7192
# LearnCodeCoursesCert      29389    206
# YearsCode                 71331     52
# YearsCodePro              51833     52
# DevType                   61302   9984
# OrgSize                   51039     10
# PurchaseInfluence         50969      3
# BuyNewTool                67963    125
# Country                   71771    180
# Currency                  51264    142
# CompTotal               38422.0    NaN
# CompFreq                  44425      3
# LanguageHaveWorkedWith    70975  25068
#
#                                                                       top  \
# ...

# %% [markdown]
# ## Initial Observations
#
# 1. Many missing values in different columns
# 2. Interesting to look at may be yearscoded vs. compensation, country and compensation, what countries use what tools
# 3. Workexp and how they learned

# %%
df["Country"].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Countries in the Survey")
plt.show()
